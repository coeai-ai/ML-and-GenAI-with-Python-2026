# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi25-coder/ML-and-GenAI-with-Python-2026/blob/main/Assignment2-Vaishnavi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1.Find the sum of first 10 natural numbers
sum=0
for i in range(1,11):
  sum+=i
print(sum)
# Out:
# 55

# %%
#Q2.Find the factorial of a number
num=int(input("enter the number"))
fact=1
for i in range(1,num+1):
  fact*=i
print(fact)
# Out:
# enter the number5
# 120

# %%
#Q3.Print fibonacci series
num=int(input("enter the number"))
x=0
y=1
z=0
while(z<=num):
  print(z)
  x=y
  y=z
  z=x+y
# Out:
# enter the number10
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
#Q4.Find the largest among 3 numbers
num1=int(input("enter the number 1:"))
num2=int(input("enter the number 2:"))
num3=int(input("enter the number 3:"))
if(num1>num2 and num1>num3):
  print(num1,"num1 is the largest!!! ")
elif(num2>num1 and num2>num3):
  print(num2,"num2 is the largest!!!")
else:
   print(num3,"num3 is the largest!!!")
# Out:
# enter the number 1:10
# enter the number 2:20
# enter the number 3:30
# 30 num3 is the largest!!!

# %%
#Q5.Create student result system:input details,input marks,claculate percentage,display grade,use:-if-elif-else and loops
name=input("enter the name of the student:")
maths=int(input("enter the marks of maths:"))
physics=int(input("enter the marks of physics :"))
english=int(input("enter the marks of english :"))
print("the result of the student",name,"is")
percentage=((maths+physics+english)/300)*100
if percentage>90:
  print("grade A")
elif percentage >80:
  print("grade B")
elif percentage >70:
  print("grade C")
else:
   print("grade D")
# Out:
# enter the name of the student:vaishnavi
# enter the marks of maths:90
# enter the marks of physics :96
# enter the marks of english :98
# the result of the student vaishnavi is
# grade A
