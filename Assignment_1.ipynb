# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi25-coder/ML-and-GenAI-with-Python-2026/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1.find the area of the rectangle
length=int(input("enter the length"))
breadth=int(input("enter the breadth"))
area=length*breadth
print("the area of the rectnagle is=",area)
# Out:
# enter the length3
# enter the breadth4
# the area of the rectnagle is= 12

# %%
#Q2.Find simple interest
p=int(input("enter the principal amount "))
r=int(input("enter the rate of interest"))
t=int(input("enter the time"))
simpleinterest=(p*r*t)/100
print("the simple interest is=",simpleinterest)
# Out:
# enter the principal amount 1000
# enter the rate of interest5
# enter the time3
# the simple interest is= 150.0

# %%
#Q3.Convert temprature from celcius to fahrenheit
cc=int(input("enter the temprature in celcius "))
fh=cc*1.8
result=fh+32
print("the result is=",result)
# Out:
# enter the temprature in celcius 28
# the result is= 82.4

# %%
#Q4.calculate the average of 3 numbers
num1=int(input("enter the number"))
num2=int(input("enter the number"))
num3=int(input("enter the number"))
avg=(num1+num2+num3)/3
print("the average of the number is="5,avg)
# Out:
# enter the number3
# enter the number4
# enter the number5
# the average of the number is= 4.0

# %%
#Q5.find the square and cube of a number
num=int(input("enter the number"))
sqaure=num**2
cube=num**3
print("the square of the number is=",sqaure)
print("the cube  of the number is=",cube)
# Out:
# enter the number4
# the square of the number is= 16
# the cube  of the number is= 64

# %%
#Q6.swap two numbers without third variable
num1=int(input("enter the number"))
num2=int(input("enter the number"))
num1,num2=num2,num1
print("num1=",num1)
print("num2=",num2)
# Out:
# enter the number5
# enter the number4
# num1= 4
# num2= 5

# %%
#Q7.create a student report program that take student details using input(),store marks in variables ,calculate total percentage ,use comments na dproper indentation
name=input("enter the name")
rollno=input("enter the roll no")
maths=int(input("enter the marks"))
sspd=int(input("enter the marks"))
physics=int(input("enter the marks"))
ids=int(input("enter the marks"))
totalmarks=maths+sspd+physics+ids
percentage=(totalmarks/400)*100
print("Report of the student....")
print("the name of the student is=",name)
print("the roll no of the student is=",98
      rollno)
print("the total marks of the student is=",totalmarks)
print("the percentage of the student is=",percentage)
# Out:
# enter the namevaishnavi
# enter the roll no70
# enter the marks100
# enter the marks98
# enter the marks96
# enter the marks95
# Report of the student....
# the name of the student is= vaishnavi
# the roll no of the student is= 70
# the total marks of the student is= 389
# the percentage of the student is= 97.25
