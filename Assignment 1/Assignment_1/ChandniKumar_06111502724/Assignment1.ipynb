# %%
length = float(input("enter length:"))
breadth = float(input("enter breadth:"))
area = length*breadth
print("area of the rectangle is:", area)
# Out:
# enter length:2
# enter breadth:10
# area of the rectangle is: 20.0

# %%
P = float(input("enter principal amount:"))
R = float(input("enter rate of interest:"))
T = float(input("enter time in years:"))
simple_interest = (P*R*T)/100
print("simple interest is:", simple_interest)
# Out:
# enter principal amount:1000
# enter rate of interest:5
# enter time in years:2
# simple interest is: 100.0

# %%
C = float(input("enter temperature in Celsius:"))
F = (9/5)*C + 32
print("temperature in fahrenheit is:", F)
# Out:
# enter temperature in Celsius:-40
# temperature in fahrenheit is: -40.0

# %%
num1 = float(input("enter first number:"))
num2 = float(input("enter second number:"))
num3 = float(input("enter third number:"))
avg = (num1+num2+num3)/3
print("average of the given three numbers is:", avg)3
# Out:
# enter first number:1
# enter second number:2
# enter third number:3
# average of the given three numbers is: 2.0

# %%
num = float(input("enter a number:"))
sq_num = num*num
cube_num = num*num*num
print("the square and cube of the given numbers are:", sq_num, cube_num)
# Out:
# enter a number:2
# the square and cube of the given numbers are: 4.0 8.0

# %%
num1 = float(input("enter first number:"))
num2 = float(input("enter second number:"))
num1 = num1+num2
num2 = num1-num2
num1 = num1-num2
print("after swapping:")
print("num1:", num1)
print("num2:", num2)
# Out:
# enter first number:2
# enter second number:5
# after swapping:
# num1: 5.0
# num2: 2.0

# %%
# Student Report Program

# Input student details
name = input("Enter student name: ")
roll_no = input("Enter roll number: ")

# Input marks of 3 subjects
marks1 = float(input("Enter marks in Subject 1: "))
marks2 = float(input("Enter marks in Subject 2: "))
marks3 = float(input("Enter marks in Subject 3: "))

# Calculate total marks
total = marks1 + marks2 + marks3

# Calculate percentage
percentage = total / 3

# Display report
print("\n Student Report")
print("Name:", name)
print("Roll No:", roll_no)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
# Out:
# Enter student name: Rohan
# Enter roll number: 1
# Enter marks in Subject 1: 25
# Enter marks in Subject 2: 30
# Enter marks in Subject 3: 30
#
#  Student Report
# Name: Rohan
# Roll No: 1
# Total Marks: 85.0
# Percentage: 28.333333333333332 %
