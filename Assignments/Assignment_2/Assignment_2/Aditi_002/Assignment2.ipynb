# %%
#Ques1)Find sum of first 10 largest numbers
sum = 0
i=1
while i<=10:

    sum = sum + i
    i += 1
print(f"Sum of First 10 natural numbers is {sum} ")
# Out:
# Sum of First 10 natural numbers is 55

# %%
#Ques2)Find factorial of a number
num = int(input("Enter your number :"))
i = 1
fact = 1
while i<=num:
    fact = fact * i
    i+=1
print(f"Factorial of given number is:{fact}")
# Out:
# Enter your number :5
# Factorial of given number is:120

# %%
#Ques3)Print Fibonaaci Series
n = int(input("Enter number of terms: "))

a = 0
b = 1
i = 1

while i <= n:
    print(a)

    c = a + b
    a = b
    b = c

    i += 1
# Out:
# Enter number of terms: 8
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
#Ques4)Find largest among three numbers
num_1=int(input("Enter your first number:"))
num_2=int(input("Enter your second number:"))
num_3=int(input("Enter your third number:"))
if num_1>num_2 and num_1>num_3:
    print(f"{num_1} is largest")
elif num_2>num_1 and num_2>num_3:
    print(f"{num_2} is largest")
else:
    print(f"{num_3} is largest")
# Out:
# Enter your first number:5
# Enter your second number:10
# Enter your third number:13
# 13 is largest

# %%
#Ques5)Student Result System
print("STUDENT RESULT SYSTEM")
student_name = input("Enter your name:")
roll_no = int(input("Enter your roll no."))
total_marks = 0
i = 1

while i <= 5:
    marks = int(input(f"Enter marks of subject {i}: "))
    total_marks = total_marks + marks
    i += 1
max_marks = 500
percentage = (total_marks/max_marks)*100
print(f"Student:{student_name}")
print(f"Roll No:{roll_no}")
print(f"TOTAL MARKS OBTAINED:{total_marks}")
print(f"TOTAL PERCENTAGE OBTAINED:{percentage}")
if total_marks>=450:
    print("GRADE OBTAINED: A")
elif total_marks>=400 and total_marks<450:
    print("GRADE OBTAINED: B")
elif total_marks>=350 and total_marks<400:
    print("GRADE OBTAINED: C")
elif total_marks>=300 and total_marks<350:
    print("GRADE OBTAINED: D")
elif total_marks>=250 and total_marks<300:
    print("GRADE OBTAINED: E")
else:
    print("GRADE OBTAINED: F")
# Out:
# STUDENT RESULT SYSTEM
# Enter your name:Aditi
# Enter your roll no.002
# Enter marks of subject 1: 98
# Enter marks of subject 2: 98
# Enter marks of subject 3: 97
# Enter marks of subject 4: 95
# Enter marks of subject 5: 96
# Student:Aditi
# Roll No:2
# TOTAL MARKS OBTAINED:484
# TOTAL PERCENTAGE OBTAINED:96.8
# GRADE OBTAINED: A
